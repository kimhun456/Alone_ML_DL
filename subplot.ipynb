# %%
import matplotlib.pyplot as plt

# 2x2 그리드를 가지는 서브플롯 생성
fig, ax = plt.subplots(2, 2)

# 각 서브플롯에 접근하여 그래프를 그릴 수 있음
ax[0, 0].plot([1, 2, 3], [1, 4, 9])
ax[0, 1].plot([1, 2, 3], [1, 2, 3])
ax[1, 0].plot([1, 2, 3], [3, 2, 1])
ax[1, 1].plot([1, 2, 3], [9, 4, 1])

plt.show()
